# %%
import pandas as pd

# %% [markdown]
# # Задание 1
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
print(pd.read_csv("ratings.csv")[['movieId', 'rating']].query('rating == 5').groupby('movieId').\
count().sort_values('rating', ascending = False).head(1).merge(pd.read_csv("movies.csv"), on = 'movieId', how = 'left'))
# Out:
#    movieId  rating                             title       genres
# 0      318   39553  Shawshank Redemption, The (1994)  Crime|Drama

# %% [markdown]
# # Задание 2
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
print('Суммарное потребление: ', sum(pd.read_csv("power.csv").query('category in list ([4, 12, 21]) & \
country in list(["Latvia", "Lithuania", "Estonia"]) & quantity > 0 & 2005<=year<=2010')['quantity']))
# Out:
# Суммарное потребление:  240580.0

# %% [markdown]
# # Задание 3
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
for imp in pd.read_html('https://fortrader.org/quotes'):
    print(imp, '\n\n')
# Out:
#                            Название     Цена  Изменение  Изменение(%)  \
# 0  EURRUB Курс евро к рублю сегодня  86.6493     0.7457        0.8681
# 1       USDRUB Курс рубля к доллару  73.1254    -0.0518       -0.0708
#
#    Обновлено
# 0        NaN
# 1        NaN
#
#
#                            Название     Цена   Изменение Изменение(%)  \
# 0  Нефть (BRENT) Курс нефти сегодня    44.83       +0.11        +0.25
# 1   Нефть (WTI) Цены на нефть (WTI)    41.81       +0.20        +0.48
# 2          Сахар котировки на сахар    12.63  нет данных   нет данных
# 3                   Газ Цена на газ     2.25      -0.001       -0.044
# 4                             CACAO  2541.00     -5.0000      -0.1964
# 5                            Coffee   116.10     +1.2500      +1.0884
# 6                              CORN   309.40      +1.800       +0.585
# 7                           Soybean   282.20       -0.10        -0.04
# 8                            cotton    62.24       -0.12        -0.19
#
# ...
